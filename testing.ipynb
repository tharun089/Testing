# %% [markdown]
# <a href="https://colab.research.google.com/github/tharun089/Testing/blob/main/testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# HI this is testing# New Section

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# /content/drive/MyDrive/Meet Recordings/Chronicle roll-back from GWS - 2025 05 05 15:25 GMT+05:30 - Chat

# %%
from google.colab import files

file_path = '/content/drive/MyDrive/Compromised Logs.csv'

try:
    files.download(file_path)
    print(f"Initiating download for: {file_path}")
except Exception as e:
    print(f"Error downloading file: {e}")
    print("Please ensure the file path is correct and you have permission to access it.")
# Out:
# Initiating download for: /content/drive/MyDrive/Compromised Logs.csv

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/Compromised Logs.csv'

try:
    df = pd.read_csv(file_path)
    print(f"Successfully loaded {file_path}. Displaying the first 5 rows and info:")
    display(df.head())
    df.info()
except FileNotFoundError:
    print(f"Error: The file at {file_path} was not found. Please ensure the path is correct.")
except Exception as e:
    print(f"An error occurred while reading the file: {e}")
# Out:
# Successfully loaded /content/drive/MyDrive/Compromised Logs.csv. Displaying the first 5 rows and info:
# /tmp/ipykernel_1351/1775731476.py:6: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
#                         Date         Device ID              Event  \
# 0  2025-03-27T11:28:34+05:30  358d4ccfe1ef011f  Device sync event
# 1  2025-03-27T11:28:14+05:30  3a90b118b587b0cb  Device sync event
# 2  2025-03-27T11:26:51+05:30  3a90b118b587b0cb  Device sync event
# 3  2025-03-27T11:26:19+05:30  358d4ccfe1ef011f  Device sync event
# 4  2025-03-27T11:26:15+05:30  385dabb65d1abc5b  Device sync event
#
#                                          Description  \
# 0  singh44sokhi , Jasbant (EST), Vodafone Idea (E...
# 1  Jindal , Eshu (RAD), Vodafone Idea's account s...
# 2  Jindal , Eshu (RAD), Vodafone Idea's account s...
# 3  singh44sokhi , Jasbant (EST), Vodafone Idea (E...
# 4  Lothe , Manasi (MUM), Vodafone Idea's account ...
#
#                               User email Device type Device model  OS version  \
# 0  jasbant.singh44sokhi@vodafoneidea.com     Android     SM-A032F  Android 13
# 1           eshu.jindal@vodafoneidea.com     Android    Nokia C12  Android 12
# 2           eshu.jindal@vodafoneidea.com     Android    Nokia C12  Android 12
# 3  jasbant.singh44sokhi@vodafoneidea.com     Android     SM-A032F  Android 13
# 4          manasi.lothe@vodafoneidea.com     Android   23028RN4DI  Android 13
#
#    Policy name  Policy status code  ...  \
# 0          NaN                 NaN  ...
# 1          NaN                 NaN  ...
# 2          NaN                 NaN  ...
# 3          NaN                 NaN  ...
# 4          NaN                 NaN  ...
#
#                                          Resource ID  \
# 0  AFiQxQ8Qgd-rouSmcd2UnuvhYV__D4s44bVTC1pCq18uG7...
# 1  AFiQxQ8bxjzl4O9Isc1FFyhbfhdakZTHjqQWB_8HC3B5lI...
# 2  AFiQxQ8bxjzl4O9Isc1FFyhbfhdakZTHjqQWB_8HC3B5lI...
# 3  AFiQxQ8Qgd-rouSmcd2UnuvhYV__D4s44bVTC1pCq18uG7...
# 4  AFiQxQ_m8mKYtN7QFxo1Rm1TbLa02MUJNTxoivN2TMVDaP...
#
#                       Serial number  iOS vendor ID            Domain  \
# 0  PDZK-AO4U-G6KW-2DY4X-5IAN-DDTN-T            NaN  vodafoneidea.com
# 1  GP2B-EVYR-F6KV-ZDVIF-TCYY-KEM5-E            NaN  vodafoneidea.com
# 2  GP2B-EVYR-F6KV-ZDVIF-TCYY-KEM5-E            NaN  vodafoneidea.com
# 3  PDZK-AO4U-G6KW-2DY4X-5IAN-DDTN-T            NaN  vodafoneidea.com
# 4  FQCE-CUND-B6DJ-PJFAA-JJR3-5KSQ-G            NaN  vodafoneidea.com
#
#   Device compliance state OS property  OS is outdated  \
# 0                 Unknown     Unknown           False
# 1                 Unknown     Unknown           False
# 2                 Unknown     Unknown           False
# 3                 Unknown     Unknown           False
# 4                 Unknown     Unknown           False
#
#    Security patch is outdated Has potentially harmful apps  Is compromised
# 0                       False                        False            True
# 1                       False                        False            True
# 2                       False                        False            True
# 3                       False                        False            True
# 4                       False                        False            True
#
# [5 rows x 35 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 35 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   Date                          100000 non-null  object
#  1   Device ID                     100000 non-null  object
#  2   Event                         100000 non-null  object
#  3   Description                   100000 non-null  object
#  4   User email                    100000 non-null  object
#  5   Device type                   100000 non-null  object
#  6   Device model                  100000 non-null  object
#  7   OS version                    100000 non-null  object
#  8   Policy name                   0 non-null       float64
#  9   Policy status code            0 non-null       float64
#  10  Policy status                 100000 non-null  object
#  11  Windows OS edition            0 non-null       float64
#  12  Failed password attempts      100000 non-null  float64
#  13  Device compromised state      100000 non-null  object
#  14  Device property               100000 non-null  object
#  15  Device setting                100000 non-null  object
#  16  Application SHA-256 hash      0 non-null       float64
#  17  Application ID                0 non-null       float64
#  18  Application state             100000 non-null  object
#  19  New value                     0 non-null       float64
#  20  Old value                     0 non-null       float64
#  21  Account state                 100000 non-null  object
#  22  Register privilege            100000 non-null  object
#  23  Device ownership              100000 non-null  object
#  24  New device ID                 0 non-null       float64
#  25  Resource ID                   100000 non-null  object
#  26  Serial number                 100000 non-null  object
#  27  iOS vendor ID                 0 non-null       float64
#  28  Domain                        100000 non-null  object
#  29  Device compliance state       100000 non-null  object
#  30  OS property                   100000 non-null  object
#  31  OS is outdated                100000 non-null  bool
#  32  Security patch is outdated    100000 non-null  bool
#  33  Has potentially harmful apps  100000 non-null  object
#  34  Is compromised                100000 non-null  bool
# dtypes: bool(3), float64(10), object(22)
# memory usage: 24.7+ MB

# %% [markdown]
# /content/drive/MyDrive/Compromised Logs.csv
